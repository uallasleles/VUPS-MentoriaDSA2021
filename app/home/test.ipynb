# %%
import vups
# Out:
# Tempo decorrido: 0.08842992782592773 s.
# c:\Users\ulp\Documents\GitHub\VUPS-MentoriaDSA2021\app\home\vups\__init__.py:215: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   return get_data(file='Arrecadacao_01-01-1998_a_31-12-2001.csv', usecols=columns, nrows=nrows, sep=',', encoding='utf-8', dtype=tax_cat_col)
# c:\Users\ulp\Documents\GitHub\VUPS-MentoriaDSA2021\app\home\vups\__init__.py:215: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   return get_data(file='Arrecadacao_01-01-1998_a_31-12-2001.csv', usecols=columns, nrows=nrows, sep=',', encoding='utf-8', dtype=tax_cat_col)

# %%
from vups import const

# %%
import watermark

# %%
# %load_ext watermark

# %%
# %watermark --iversions
# Out:
# sys      : 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# watermark: 2.2.0
# pandas   : 1.3.2

# %%
df = vups.datasets.microdados()
# Out:
# ###################################################################
# GetData_FromParquet
# Tempo decorrido: 1.581111192703247 s.
# ###################################################################

# %%
vups.convert_to_parquet(df)

# %%
import pandas as pd

# %%
import os

# %%
df_pqt = pd.read_parquet(os.path.join(const.DATADIR + 'df.parquet'))

# %%
df_pqt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1651537 entries, 0 to 1651536
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   DataNotificacao          1651537 non-null  category
#  1   DataCadastro             1651537 non-null  category
#  2   DataDiagnostico          1651537 non-null  category
#  3   DataColeta_RT_PCR        810766 non-null   category
#  4   DataColetaTesteRapido    600675 non-null   category
#  5   DataColetaSorologia      87834 non-null    category
#  6   DataColetaSorologiaIGG   134953 non-null   category
#  7   DataEncerramento         1414956 non-null  category
#  8   DataObito                14830 non-null    category
#  9   Classificacao            1651537 non-null  category
#  10  Evolucao                 1651537 non-null  category
#  11  CriterioConfirmacao      1651537 non-null  category
#  12  StatusNotificacao        1651537 non-null  category
# ...

# %%
for i in df_pqt.head().itertuples():
    print(i[0], i[1])
# Out:
# 0 2021-07-05
# 1 2021-07-05
# 2 2021-07-05
# 3 2021-07-05
# 4 2021-07-05

# %%
from tqdm import tqdm

# %%
from tqdm.notebook import trange, tqdm

# %%
for row in tqdm(df_pqt.itertuples(), total=df_pqt.shape[0]):
   print("row", row[0])
# Out:
#   0%|          | 410/1651537 [00:00<06:46, 4059.29it/s]
# row 0
# row 1
# row 2
# row 3
# row 4
# row 5
# row 6
# row 7
# row 8
# row 9
# row 10
# row 11
# row 12
# row 13
# row 14
# row 15
# row 16
# row 17
# row 18
# row 19
# row 20
# row 21
# row 22
# row 23
# row 24
# row 25
# row 26
# row 27
# row 28
# row 29
# row 30
# row 31
# row 32
# row 33
# row 34
# row 35
# row 36
# row 37
# row 38
# row 39
# row 40
# row 41
# row 42
# row 43
# row 44
# row 45
# row 46
# row 47
# row 48
# row 49
# row 50
# row 51
# row 52
# row 53
# row 54
# row 55
# row 56
# row 57
# row 58
# row 59
# row 60
# row 61
# row 62
# row 63
# row 64
# row 65
# row 66
# row 67
# row 68
# row 69
# row 70
# row 71
# row 72
# row 73
# row 74
# row 75
# row 76
# row 77
# row 78
# row 79
# row 80
# row 81
# row 82
# row 83
# row 84
# row 85
# row 86
# row 87
# row 88
# row 89
# row 90
# row 91
# row 92
# row 93
# row 94
# row 95
# row 96
# row 97
# row 98
# row 99
# row 100
# row 101
# row 102
# row 103
# row 104
# ...

# %%
for i in trange(len(df_pqt)):
    print(df_pqt.itertuples(i))
    pass
# Out:
#   0%|          | 0/1651537 [00:00<?, ?it/s]
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-016c946c9f04> in <module>
#       1 for i in trange(len(df_pqt)):
# ----> 2     print(df_pqt.itertuples(i))
#       3     pass
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in itertuples(self, index, name)
#    1345                 name, fields, rename=True
#    1346             )
# -> 1347             return map(itertuple._make, zip(*arrays))
#    1348
#    1349         # fallback to regular tuples
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __iter__(self)
#     750         if not isinstance(self._values, np.ndarray):
#     751             # Check type instead of dtype to catch DTA/TDA
# --> 752             return iter(self._values)
#     753         else:
#     754             return map(self._values.item, range(self._values.size))
#
# ...
