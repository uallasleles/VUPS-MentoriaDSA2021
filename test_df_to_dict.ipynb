# %%
from app.home.vups import datasets

# %%
microdados = datasets.Datasets.microdados()
df = microdados.filter(items=['DataNotificacao', 'Municipio', 'Classificacao', 'DataObito', 'RacaCor'])[0:100]

# %%
df.head()
# Out:
#   DataNotificacao           Municipio Classificacao DataObito  RacaCor
# 0      2021-07-05  CONCEICAO DA BARRA      Suspeito       NaT    Parda
# 1      2021-07-05  CONCEICAO DA BARRA      Suspeito       NaT    Parda
# 2      2021-07-05               PIUMA      Suspeito       NaT    Parda
# 3      2021-07-05               SERRA      Suspeito       NaT    Parda
# 4      2021-07-05  SAO ROQUE DO CANAA   Descartados       NaT  Amarela

# %%
df.to_dict()
# Out:
# {'DataNotificacao': {0: Timestamp('2021-07-05 00:00:00'),
#   1: Timestamp('2021-07-05 00:00:00'),
#   2: Timestamp('2021-07-05 00:00:00'),
#   3: Timestamp('2021-07-05 00:00:00'),
#   4: Timestamp('2021-07-05 00:00:00'),
#   5: Timestamp('2021-07-05 00:00:00'),
#   6: Timestamp('2021-07-05 00:00:00'),
#   7: Timestamp('2021-07-05 00:00:00'),
#   8: Timestamp('2021-07-05 00:00:00'),
#   9: Timestamp('2021-07-05 00:00:00'),
#   10: Timestamp('2021-07-05 00:00:00'),
#   11: Timestamp('2021-07-05 00:00:00'),
#   12: Timestamp('2021-07-05 00:00:00'),
#   13: Timestamp('2021-07-05 00:00:00'),
#   14: Timestamp('2021-07-05 00:00:00'),
#   15: Timestamp('2021-07-05 00:00:00'),
#   16: Timestamp('2021-07-05 00:00:00'),
#   17: Timestamp('2021-07-05 00:00:00'),
#   18: Timestamp('2021-07-05 00:00:00'),
#   19: Timestamp('2021-07-05 00:00:00'),
#   20: Timestamp('2021-07-05 00:00:00'),
#   21: Timestamp('2021-07-05 00:00:00'),
#   22: Timestamp('2021-07-05 00:00:00'),
# ...

# %%
# orient: str {‘dict’, ‘list’, ‘series’, ‘split’, ‘records’, ‘index’}

# %%
cols = [{k, v} for k, v in enumerate(df.columns.to_list())]

# %%
[ v for k, v in cols]
# Out:
# ['DataNotificacao', 'Municipio', 'Classificacao', 3, 'RacaCor']

# %%
[row for row in df.to_dict(orient='records')]
# Out:
# [{'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'CONCEICAO DA BARRA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'CONCEICAO DA BARRA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'PIUMA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'SERRA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'SAO ROQUE DO CANAA',
#   'Classificacao': 'Descartados',
#   'DataObito': NaT,
#   'RacaCor': 'Amarela'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'ANCHIETA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
# ...

# %%
[row for row in df.to_dict(orient='records')]
# Out:
# [{'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'CONCEICAO DA BARRA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'CONCEICAO DA BARRA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'PIUMA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'SERRA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
#   'RacaCor': 'Parda'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'SAO ROQUE DO CANAA',
#   'Classificacao': 'Descartados',
#   'DataObito': NaT,
#   'RacaCor': 'Amarela'},
#  {'DataNotificacao': Timestamp('2021-07-05 00:00:00'),
#   'Municipio': 'ANCHIETA',
#   'Classificacao': 'Suspeito',
#   'DataObito': NaT,
# ...
